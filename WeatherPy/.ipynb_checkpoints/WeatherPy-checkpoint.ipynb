# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from scipy import stats

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 615

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sitka
# Processing Record 2 of Set 1 | invercargill
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | wailua homesteads
# Processing Record 6 of Set 1 | stanley
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | aasiaat
# Processing Record 12 of Set 1 | utrik
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | gurupa
# Processing Record 15 of Set 1 | bilibino
# Processing Record 16 of Set 1 | kijang
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | papatowai
# Processing Record 19 of Set 1 | waitangi
# Processing Record 20 of Set 1 | mochudi
# Processing Record 21 of Set 1 | kingston
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              sitka  57.0531 -135.3300      6.94        81         100
# 1       invercargill -46.4000  168.3500      7.79        91         100
# 2       longyearbyen  78.2186   15.6401     -3.09        68          75
# 3            college  64.8569 -147.8028     10.02        51          40
# 4  wailua homesteads  22.0669 -159.3780     23.94        77          75
#
#    Wind Speed Country        Date
# 0        5.14      US  1714935145
# 1        5.81      NZ  1714934859
# 2        2.57      SJ  1714935524
# 3        3.60      US  1714935147
# 4        7.20      US  1714935148

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    sitka  57.0531 -135.3300      6.94        81         100
# 1             invercargill -46.4000  168.3500      7.79        91         100
# 2             longyearbyen  78.2186   15.6401     -3.09        68          75
# 3                  college  64.8569 -147.8028     10.02        51          40
# 4        wailua homesteads  22.0669 -159.3780     23.94        77          75
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1714935145
# 1              5.81      NZ  1714934859
# 2              2.57      SJ  1714935524
# 3              3.60      US  1714935147
# 4              7.20      US  1714935148

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_value = city_data_df['Lat']
y_value = city_data_df['Max Temp']
plt.scatter(x_value, y_value, edgecolor='black')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature (2022-10-18)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. temperature
x_value = city_data_df['Lat']
y_value = city_data_df['Humidity']
plt.scatter(x_value, y_value, edgecolor='black')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity (2022-10-18)')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. temperature
x_value = city_data_df['Lat']
y_value = city_data_df['Cloudiness']
plt.scatter(x_value, y_value, edgecolor='black')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. temperature
x_value = city_data_df['Lat']
y_value = city_data_df['Wind Speed']
plt.scatter(x_value, y_value, edgecolor='black')

# Incorporate the other graph properties
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2022-10-18)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots\
def linear_regression_plots(x_value, y_value):

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    sitka  57.0531 -135.3300      6.94        81         100
# 2             longyearbyen  78.2186   15.6401     -3.09        68          75
# 3                  college  64.8569 -147.8028     10.02        51          40
# 4        wailua homesteads  22.0669 -159.3780     23.94        77          75
# 5                  stanley  54.8680   -1.6985     12.73        86          20
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      US  1714935145
# 2              2.57      SJ  1714935524
# 3              3.60      US  1714935147
# 4              7.20      US  1714935148
# 5              3.09      GB  1714935148

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        invercargill -46.4000  168.3500      7.79        91         100
# 6           grytviken -54.2811  -36.5092      3.23        95         100
# 7             ushuaia -54.8000  -68.3000      2.81        75         100
# 9           adamstown -25.0660 -130.1015     21.45        64          65
# 13             gurupa  -1.4050  -51.6400     29.84        73         100
#
#          Wind Speed Country        Date
# City_ID
# 1              5.81      NZ  1714934859
# 6              3.44      GS  1714935149
# 7              9.77      AR  1714935149
# 9              8.06      PN  1714935150
# 13             1.77      BR  1714935152

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Max Temp']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.annotate(line_eq,(0,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7740651320821711

# %%
# Linear regression on Southern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Max Temp']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.annotate(line_eq,(-22,10),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.698320275142346

# %% [markdown]
# **Discussion about the linear relationship:** The line of regression for the northern and southern hemispheres show a clear relationship between max temperature and latitude meaning, the closer to the equater the higher the temperature.

# %%
# Northern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Humidity']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(45,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.05892354678995904

# %%
# Southern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Humidity']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-55,18),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 7.110307816692902e-05

# %% [markdown]
# **Discussion about the linear relationship:** The nearly 0 r-value indicates there is no relationship between humidity and latitude in both the northern and southern hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Cloudiness']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(45,41),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.011443905912940972

# %%
# Southern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Cloudiness']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-26,57),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.008473334711507397

# %% [markdown]
# **Discussion about the linear relationship:** The nearly 0 r-value indicates there is no relationship between cloudiness and latitude in both the northern and southern hemispheres..

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = northern_hemi_df['Lat']
y_value = northern_hemi_df['Wind Speed']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(50,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.0018901529114285364

# %%
# Southern Hemisphere
slope, intercept, rvalue, pvalue, stderr = stats.linregress(x_value, y_value)
regress_values = x_value * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

# Create Plot
x_value = southern_hemi_df['Lat']
y_value = southern_hemi_df['Wind Speed']
linear_regression_plots(x_value, y_value)

plt.scatter(x_value, y_value)
plt.plot(x_value, regress_values, 'r-')

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-20,13),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.030422148666580676

# %% [markdown]
# **Discussion about the linear relationship:** The nearly 0 r-value indicates there is no relationship between wind speed and latitude in both the northern and southern hemispheres.
